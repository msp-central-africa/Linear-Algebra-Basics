# %%
                # Outils Scientifique
# on import la boite a outils pour les calculs matriciels
import numpy as outil_matrix
#from scipy import misc as outil_image

# %%
import matplotlib.pyplot as outil_image

# %%
# affichage directe de l'image
# %matplotlib inline

# %%
image_a_traiter = "nathan.jpg"

# %%
# Transformation de l'image "nathan.jpg" en matrice exploitatable
image_matrice = outil_affichage.imread(image_a_traiter)

# %%
# affichage des caracteristiques de l'image
# (HAUTEUR, LARGEUR, DIMENSION)
# HAUTEUR : nombres de lignes (pixels)
# LARGEUR : nombres de colonnes (pixels)
# PROFONDEUR : 
image_matrice.shape
# Out:
# (4160, 2080, 3)

# %%
outil_affichage.imshow(image_matrice)

# %%
test_image = image_matrice.dot(2)

# %%
outil_affichage.imshow(test_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
test_image.shape
# Out:
# (4160, 2080)

# %%
outil_affichage.imshow(image_matrice * 0)
